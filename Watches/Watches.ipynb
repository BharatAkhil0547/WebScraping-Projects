# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager 
from selenium.webdriver.common.by import By
import pandas as pd
import time

# %%
driver=webdriver.Chrome(executable_path="C:\\BrowserDrivers\\chromedriver.exe")
driver.get("https://www.watchfinder.co.uk/new-arrivals")
#data-testid="watchItem"
# data-testid="searchResultContainer"
model=driver.find_elements(By.XPATH,"//div[@data-testid='searchResultContainer']")
print(len(model))
# Out:
# C:\Users\chaitu\AppData\Local\Temp/ipykernel_23240/3464031119.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path="C:\\BrowserDrivers\\chromedriver.exe")
# 1

# %%
data=[]
for i in range(1,45):
    expr=f"//div[@data-testid='watchItem'][{i}]"
#     expr1=f"//div[@data-testid='watchModelNumber'][{i}]"
    a=driver.find_element(By.XPATH,expr)
    x=[i for i in a.text.split('\n')]
    l=x.index('Box:')
    x=x[1:l]
    k=x[-1].split('£')
    k=k[1:]
    if len(k)==1:
        k.insert(0,'NULL')
    print([x[0],x[1],x[2],k[0],k[1]])
    data.append([x[0],x[1],x[2],k[0],k[1]])
# Out:
# ['Rolex', 'Datejust 41', '126334', 'NULL', '11,350']
# ['Panerai', 'Luminor Marina', 'PAM01313', 'NULL', '5,840']
# ['Panerai', 'Luminor Marina', 'PAM00392', 'NULL', '5,180']
# ['Jaeger-LeCoultre', 'Polaris', '9068180', 'NULL', '9,460']
# ['Tag Heuer', 'Monaco', 'CBL2118.FC6518', 'NULL', '9,165']
# ['Grand Seiko', 'Heritage Collection', 'SLGA007', 'NULL', '9,165']
# ['H. Moser and Cie', 'Endeavour', '321.503-015', 'NULL', '16,165']
# ['Girard Perregaux', 'Laureato', '81000-11-131-11A', 'NULL', '13,695']
# ['IWC', 'Pilot’s Chrono', 'IW370603', 'NULL', '4,375']
# ['Jaeger-LeCoultre', 'Reverso Squadra Lady', '7068721', 'NULL', '4,160']
# ['Omega', 'Aqua Terra 150m Gents', '220.12.38.20.02.001', 'NULL', '4,660']
# ['Baume et Mercier', 'Clifton', '10399', 'NULL', '1,690']
# ['Breitling', 'Colt Auto', 'A13388', 'NULL', '3,425']
# ['Maurice Lacroix', 'Miros Collection', 'MI1098-SS042-130', 'NULL', '730']
# ['Chopard', 'Mille Miglia', '168995-3002', 'NULL', '5,095']
# ...

# %%
data
# Out:
# [['Rolex', 'Datejust 41', '126334', 'NULL', '11,350'],
#  ['Panerai', 'Luminor Marina', 'PAM01313', 'NULL', '5,840'],
#  ['Panerai', 'Luminor Marina', 'PAM00392', 'NULL', '5,180'],
#  ['Jaeger-LeCoultre', 'Polaris', '9068180', 'NULL', '9,460'],
#  ['Tag Heuer', 'Monaco', 'CBL2118.FC6518', 'NULL', '9,165'],
#  ['Grand Seiko', 'Heritage Collection', 'SLGA007', 'NULL', '9,165'],
#  ['H. Moser and Cie', 'Endeavour', '321.503-015', 'NULL', '16,165'],
#  ['Girard Perregaux', 'Laureato', '81000-11-131-11A', 'NULL', '13,695'],
#  ['IWC', 'Pilot’s Chrono', 'IW370603', 'NULL', '4,375'],
#  ['Jaeger-LeCoultre', 'Reverso Squadra Lady', '7068721', 'NULL', '4,160'],
#  ['Omega', 'Aqua Terra 150m Gents', '220.12.38.20.02.001', 'NULL', '4,660'],
#  ['Baume et Mercier', 'Clifton', '10399', 'NULL', '1,690'],
#  ['Breitling', 'Colt Auto', 'A13388', 'NULL', '3,425'],
#  ['Maurice Lacroix', 'Miros Collection', 'MI1098-SS042-130', 'NULL', '730'],
# ...

# %%
driver=webdriver.Chrome(executable_path="C:\\BrowserDrivers\\chromedriver.exe")
driver.get("https://www.watchfinder.co.uk/new-arrivals")
links=driver.find_elements(By.XPATH,"//a[@data-testid='watchLink']")
print(len(links))
# Out:
# C:\Users\chaitu\AppData\Local\Temp/ipykernel_23240/3143920327.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path="C:\\BrowserDrivers\\chromedriver.exe")
# 44

# %%
for i in links:
    print(i.get_attribute('href'))
# Out:
# https://www.watchfinder.co.uk/Rolex/Datejust%2041/126334/38956/item/247719
# https://www.watchfinder.co.uk/Panerai/Luminor%20Marina/PAM01313/55291/item/247247
# https://www.watchfinder.co.uk/Panerai/Luminor%20Marina/PAM00392/23833/item/246632
# https://www.watchfinder.co.uk/Jaeger-LeCoultre/Polaris/9068180/50433/item/246759
# https://www.watchfinder.co.uk/Tag%20Heuer/Monaco/CBL2118.FC6518/56248/item/246515
# https://www.watchfinder.co.uk/Grand%20Seiko/Heritage%20Collection/SLGA007/54082/item/245639
# https://www.watchfinder.co.uk/H.%20Moser%20and%20Cie/Endeavour/321.503-015/48116/item/245261
# https://www.watchfinder.co.uk/Girard%20Perregaux/Laureato/81000-11-131-11A/34217/item/245257
# https://www.watchfinder.co.uk/IWC/Pilot%E2%80%99s%20Chrono/IW370603/35666/item/245082
# https://www.watchfinder.co.uk/Jaeger-LeCoultre/Reverso%20Squadra%20Lady/7068721/50834/item/245079
# https://www.watchfinder.co.uk/Omega/Aqua%20Terra%20150m%20Gents/220.12.38.20.02.001/42670/item/245073
# ...

# %%
k=0
for i in links:
    data[k].append(i.get_attribute('href'))
    k=k+1

# %%
data
# Out:
# [['Rolex',
#   'Datejust 41',
#   '126334',
#   'NULL',
#   '11,350',
#   'https://www.watchfinder.co.uk/Rolex/Datejust%2041/126334/38956/item/247719'],
#  ['Panerai',
#   'Luminor Marina',
#   'PAM01313',
#   'NULL',
#   '5,840',
#   'https://www.watchfinder.co.uk/Panerai/Luminor%20Marina/PAM01313/55291/item/247247'],
#  ['Panerai',
#   'Luminor Marina',
#   'PAM00392',
#   'NULL',
#   '5,180',
#   'https://www.watchfinder.co.uk/Panerai/Luminor%20Marina/PAM00392/23833/item/246632'],
#  ['Jaeger-LeCoultre',
#   'Polaris',
#   '9068180',
#   'NULL',
#   '9,460',
#   'https://www.watchfinder.co.uk/Jaeger-LeCoultre/Polaris/9068180/50433/item/246759'],
#  ['Tag Heuer',
#   'Monaco',
#   'CBL2118.FC6518',
#   'NULL',
#   '9,165',
#   'https://www.watchfinder.co.uk/Tag%20Heuer/Monaco/CBL2118.FC6518/56248/item/246515'],
#  ['Grand Seiko',
#   'Heritage Collection',
#   'SLGA007',
#   'NULL',
#   '9,165',
# ...

# %%
# a=[]
# keys=['Box', 'Papers', 'Year', 'Product Code' 'Case Size', 'Case Material', 'Movement', 'Bracelet Material', 'Dial Type', 'Water Resistance']
# for i in data:
#     driver=webdriver.Chrome(executable_path="C:\\BrowserDrivers\\chromedriver.exe")
#     driver.get(i[5])
# #     img=driver.find_element(By.CSS_SELECTOR,"div[class='owl-item active center'] img")
#     k=driver.find_element(By.XPATH,"//div[@id='specification-content'][1]")
#     desc=driver.find_element(By.CSS_SELECTOR,"p[itemprop='description']")
#     x=[i for i in k.text.split('\n')]
#     data_dict = [value.strip() for key, value in (item.split(":") for item in x) if key in keys]
#     data_dict1 = {key:value.strip() for key, value in (item.split(":") for item in x) if key in keys}
    
#     print(data_dict1)
#     print(len(data_dict))
# #     print(img.get_attribute('srcset'))
#     print(desc.text)
#     a.append([data_dict,desc.text])
#     driver.close()
a=[]
keys=['Box', 'Papers', 'Year', 'Product Code','Bracelet' ,'Case Size', 'Case Material', 'Movement', 'Bracelet Material', 'Dial Type', 'Water Resistance']
for i in data:
    driver=webdriver.Chrome(executable_path="C:\\BrowserDrivers\\chromedriver.exe")
    driver.get(i[5])
#     img=driver.find_element(By.XPATH,"(//img)[28]")
    k=driver.find_element(By.XPATH,"//div[@id='specification-content'][1]")
    desc=driver.find_element(By.CSS_SELECTOR,"p[itemprop='description']")
    x=[i for i in k.text.split('\n')]
    print(x)
    data_dict = [value.strip() for key, value in (item.split(":") for item in x) if key in keys]
    data_dict1 = {key:value.strip() for key, value in (item.split(":") for item in x) if key in keys}    
    print(data_dict)
    print(data_dict1)
    print(len(data_dict))
    print(len(data_dict1))
    print(desc.text)
    a.append([data_dict,desc.text])
    driver.close()
# Out:
# C:\Users\chaitu\AppData\Local\Temp/ipykernel_23240/3635493140.py:22: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path="C:\\BrowserDrivers\\chromedriver.exe")
# ['Box: Yes', 'Papers: Yes', 'Year: 2021', 'Product Code: 247719', 'Manufacturer Warranty: 2 years 11 Months remaining', 'Watchfinder Warranty: 24 months', 'Case Size: 41 MM', 'Case Material: Steel & White Gold', 'Movement: Automatic', 'Bracelet Material: Steel (Oyster)', 'Dial Type: Slate Roman Numeral', 'Water Resistance: 100 metres', 'Location: Call to view']
# ['Yes', 'Yes', '2021', '247719', '41 MM', 'Steel & White Gold', 'Automatic', 'Steel (Oyster)', 'Slate Roman Numeral', '100 metres']
# ...

# %%
for i in a:
    print(i[0])
    print(i[1])
# Out:
# ['Yes', 'Yes', '2021', '247719', '41 MM', 'Steel & White Gold', 'Automatic', 'Steel (Oyster)', 'Slate Roman Numeral', '100 metres']
# In 2016 the Datejust 41 replaced the almost identical Datejust II, which itself was an updated and larger version of the original 36mm Datejust, one of Rolex’s most loved models and produced without interruption since its launch in 1945. With its fluted bezel and cyclops magnifier above the date aperture at 3 o'clock, it’s a timeless classic. This stunning ‘Wimbledon’ version is so-called due to the slate-grey dial with black Roman numerals outlined in the vibrant green of a tennis lawn. The 41mm case is steel and white gold and It comes on a classic steel Oyster bracelet. Water resistant to 100 metres, it’s driven by a Caliber 3235 which holds a power reserve of 70 hours. This is one of the most attractive dials found in any Datejust model and is popular among the Rolex cognoscenti.
# ...

# %%
k=0
for i in a:
    for j in i[0]:
        data[k].append(j)
    data[k].append(i[1])
    k=k+1

# %% [markdown]
# # Gender | caseshape | details

# %%
for i in data:
    i.append("NULL")
    i.append("NULL")
    i.append("NULL")

# %%
for i in data:
    if i[-1]=="£":
        i.append("Titanium")

# %% [markdown]
# # currency

# %%
for i in data:
    i.append("£")

# %%
for i in data:
    print(len(i))
# Out:
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27
# 27

# %% [markdown]
# # color

# %%
color=[]
for i in data:
    if '-' in i[13]:
        k=i[13].index('-')
        i.append(i[13][k+1:].strip())
    elif "Steel" in i[13]:
        i.append("Steel")
    else:
        i.append(i[13])

# %%
import pandas as pd
# {'Box': 'Yes', 'Papers': 'Yes', 'Year': '2021', 'Product Code': '248083', 'Case Size': '41 MM', 'Case Material': 'Steel & White Gold', 'Movement': 'Automatic', 'Bracelet': 'Steel (Jubilee) (length 18.5 cm)', 'Dial Type': 'Slate Roman Numeral', 'Water Resistance': '100 metres'}
df=pd.DataFrame(data,columns=["brand","name","modelNo","price","finalPrice","url","Box","Papers","Year","Product Code",'Case Size','Case Material','Movement','Bracelet','Dial Type','Water Resistance',"Description","Gender","Case Shape","details","Currency","bandColor","condition","estimatedRetailPrice","images","model","fetchDate"])
df.to_csv("C:\\Users\\chaitu\\Desktop\\Watches.csv",index=False)

# %%
keys=['Box', 'Papers', 'Year',  'Case Size', 'Case Material', 'Movement', 'Bracelet Material', 'Dial Type', 'Water Resistance', ]

# %%
driver=webdriver.Chrome(executable_path="C:\\BrowserDrivers\\chromedriver.exe")
driver.get("https://www.watchfinder.co.uk/new-arrivals")
elements=driver.find_element(By.XPATH,'(//div)[125]')
print(elements)
# Out:
# C:\Users\chaitu\AppData\Local\Temp/ipykernel_5568/3652580502.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path="C:\\BrowserDrivers\\chromedriver.exe")
# <selenium.webdriver.remote.webelement.WebElement (session="ca541df7b4a24dd3e382e1a3139fa479", element="8503fb2a-7649-40c7-8c70-3d578f650c92")>

# %%
a=[i.split(':')[-1].strip() for i in a]
k=0
for i in a:
    data[k].append(i)
    k=k+1

# %%
retail=[]
keys=['Product Code']
for i in data:
    driver=webdriver.Chrome(executable_path="C:\\BrowserDrivers\\chromedriver.exe")
    driver.get(i[5])
    try:
        k=driver.find_element(By.XPATH,"(//span[@class='product--savingAmount'])[1]")
        print(k.text)
        retail.append(k.text)
    except:
        print("NULL")
        retail.append("NULL")
    driver.close()
# Out:
# C:\Users\chaitu\AppData\Local\Temp/ipykernel_5568/228489977.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path="C:\\BrowserDrivers\\chromedriver.exe")
# Save £14,645
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# Save £30,470
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# Save £2,030
# Save £460
# NULL
# Save £1,725
# Save £1,005
# Save £990
# Save £1,670
# Save £980
# Save £1,005
# Save £990
# Save £770
# Save £885
# NULL
# Save £635
# Save £7,905
# NULL
# Save £1,650
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL

# %%
k=0
for i in retail:
    data[k].append(i)
    k=k+1

# %%
condition=[]
for i in data:
    driver=webdriver.Chrome(executable_path="C:\\BrowserDrivers\\chromedriver.exe")
    driver.get(i[5])
    n=[]
    content=driver.find_element(By.CSS_SELECTOR,"meta[itemprop='itemCondition']")
    print(content.get_attribute('content'))
    n.append(content.get_attribute('content'))
    try:
        ERP=driver.find_element(By.XPATH,"//span[@class='product--rrp']")
        if ERP.text.split(':')[-1].strip()!="Discontinued":
            print(ERP.text.split(':')[-1].strip())
            n.append(ERP.text.split(':')[-1].strip())
        else:
            print("NULL")
            n.append("NULL")
        
    except:
        n.append("NULL")
    
    driver.close()
    print(n)
    condition.append(n)
# Out:
# C:\Users\chaitu\AppData\Local\Temp/ipykernel_23240/1626496176.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path="C:\\BrowserDrivers\\chromedriver.exe")
# RefurbishedCondition
# £8,650
# ['RefurbishedCondition', '£8,650']
# RefurbishedCondition
# £7,600
# ['RefurbishedCondition', '£7,600']
# RefurbishedCondition
# NULL
# ['RefurbishedCondition', 'NULL']
# RefurbishedCondition
# £10,800
# ['RefurbishedCondition', '£10,800']
# RefurbishedCondition
# £6,800
# ['RefurbishedCondition', '£6,800']
# RefurbishedCondition
# £8,200
# ['RefurbishedCondition', '£8,200']
# RefurbishedCondition
# NULL
# ['RefurbishedCondition', 'NULL']
# RefurbishedCondition
# NULL
# ['RefurbishedCondition', 'NULL']
# RefurbishedCondition
# NULL
# ['RefurbishedCondition', 'NULL']
# RefurbishedCondition
# NULL
# ['RefurbishedCondition', 'NULL']
# RefurbishedCondition
# £5,600
# ['RefurbishedCondition', '£5,600']
# ...

# %%
k=0
for i in condition:
    data[k].append(i[0])
    data[k].append(i[1])
    k=k+1

# %%
images=[]
for i in data:
    driver=webdriver.Chrome(executable_path="C:\\BrowserDrivers\\chromedriver.exe")
    driver.get(i[5])
    img=driver.find_element(By.XPATH,"(//source)[19]")
    print(f"{img.get_attribute('srcset')}")
    images.append(f"{img.get_attribute('srcset')}")
# Out:
# C:\Users\chaitu\AppData\Local\Temp/ipykernel_23240/3952765979.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path="C:\\BrowserDrivers\\chromedriver.exe")
# https://images.watchfinder.co.uk/images/watchfinderimages/media/views/0/2022/10/06/promo_syw-md.jpg;quality=90;h=450, https://images.watchfinder.co.uk/images/watchfinderimages/media/views/0/2022/10/06/promo_syw-md.jpg;quality=55;h=900 2x
# https://images.watchfinder.co.uk/imgv3/stock/247247/Panerai-LuminorMarina-PAM01313-247247-230511-105804.jpg;quality=90;h=80, https://images.watchfinder.co.uk/imgv3/stock/247247/Panerai-LuminorMarina-PAM01313-247247-230511-105804.jpg;quality=55;h=160 2x
# https://images.watchfinder.co.uk/images/watchfinderimages/media/views/0/2022/10/06/promo_syw-md.jpg;quality=90;h=450, https://images.watchfinder.co.uk/images/watchfinderimages/media/views/0/2022/10/06/promo_syw-md.jpg;quality=55;h=900 2x
# ...

# %%
k=0
for i in images:
    data[k].append(i)
    k=k+1

# %%
for i in data:
    i.append(i[1])

# %%
for i in data:
    i.append("16/05/2023")

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\chaitu\\Desktop\\Watches.csv")
df
# Out:
#                     brand                       name                modelNo  \
# 0                   Rolex                Datejust 41                 126334
# 1                 Panerai             Luminor Marina               PAM01313
# 2                 Panerai             Luminor Marina               PAM00392
# 3        Jaeger-LeCoultre                    Polaris                9068180
# 4               Tag Heuer                     Monaco         CBL2118.FC6518
# 5             Grand Seiko        Heritage Collection                SLGA007
# 6        H. Moser and Cie                  Endeavour            321.503-015
# 7        Girard Perregaux                   Laureato       81000-11-131-11A
# 8                     IWC             Pilot’s Chrono               IW370603
# 9        Jaeger-LeCoultre       Reverso Squadra Lady                7068721
# 10                  Omega      Aqua Terra 150m Gents    220.12.38.20.02.001
# ...

# %%
k=0
for i in df['images']:
    i=images[k]
    print(i)
    k=k+1
# Out:
# https://images.watchfinder.co.uk/images/watchfinderimages/media/views/0/2022/10/06/promo_syw-md.jpg;quality=90;h=450, https://images.watchfinder.co.uk/images/watchfinderimages/media/views/0/2022/10/06/promo_syw-md.jpg;quality=55;h=900 2x
# https://images.watchfinder.co.uk/imgv3/stock/247247/Panerai-LuminorMarina-PAM01313-247247-230511-105804.jpg;quality=90;h=80, https://images.watchfinder.co.uk/imgv3/stock/247247/Panerai-LuminorMarina-PAM01313-247247-230511-105804.jpg;quality=55;h=160 2x
# https://images.watchfinder.co.uk/images/watchfinderimages/media/views/0/2022/10/06/promo_syw-md.jpg;quality=90;h=450, https://images.watchfinder.co.uk/images/watchfinderimages/media/views/0/2022/10/06/promo_syw-md.jpg;quality=55;h=900 2x
# https://images.watchfinder.co.uk/imgv3/stock/246759/Jaeger-LeCoultre-Polaris-9068180-246759-230504-140438.jpg;quality=90;h=80, https://images.watchfinder.co.uk/imgv3/stock/246759/Jaeger-LeCoultre-Polaris-9068180-246759-230504-140438.jpg;quality=55;h=160 2x
# ...

# %%
df['images']=images

# %%
df['Currency']=[f"{'£'}" for i in range(44)]
df.to_csv("C:\\Users\\chaitu\\Desktop\\Watches.csv",encoding='utf-8-sig')
